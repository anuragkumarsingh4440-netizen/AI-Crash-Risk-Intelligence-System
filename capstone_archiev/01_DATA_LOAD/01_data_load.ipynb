# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **1. Load the full crash dataset without errors.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from warnings import filterwarnings
filterwarnings('ignore')

# %%
data = pd.read_csv('/content/drive/MyDrive/CAPSTONE/CAPSTONE_PROJECT/0_dataset/1.RAW_DATA/Crash_Reporting_-_Drivers_Data.csv')

# %%
df = data.copy()

# %%
df.head(3)
# Out:
#   Report Number Local Case Number Agency Name       ACRS Report Type  \
# 0   MCP3126006X         250037402  MONTGOMERY           Injury Crash
# 1   MCP2349001B         250037516  MONTGOMERY  Property Damage Crash
# 2   MCP296500BC         250033157  MONTGOMERY  Property Damage Crash
#
#           Crash Date/Time              Route Type                Road Name  \
# 0  08/21/2025 05:21:00 PM  Maryland (State) Route                      NaN
# 1  08/22/2025 10:44:00 AM      Interstate (State)  EISENHOWER MEMORIAL HWY
# 2  07/25/2025 11:55:00 AM           Bicycle Route                      NaN
#
#                                    Cross-Street Name Off-Road Description  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  NEW HAMPSHIRE AVE (SB/L) NORBECK RD (WB/L) SPE...                  NaN
#
#   Municipality  ... Vehicle Going Dir Speed Limit Driverless Vehicle  \
# ...

# %%
df['Crash Date/Time'] = pd.to_datetime(df['Crash Date/Time'])

# %%
df['Crash Date/Time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205539 entries, 0 to 205538
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Report Number                  205539 non-null  object
#  1   Local Case Number              205539 non-null  object
#  2   Agency Name                    205539 non-null  object
#  3   ACRS Report Type               205539 non-null  object
#  4   Crash Date/Time                205539 non-null  datetime64[ns]
#  5   Route Type                     185420 non-null  object
#  6   Road Name                      182250 non-null  object
#  7   Cross-Street Name              168429 non-null  object
#  8   Off-Road Description           19079 non-null   object
#  9   Municipality                   19126 non-null   object
#  10  Related Non-Motorist           6687 non-null    object
#  11  Collision Type                 204954 non-null  object
# ...

# %%
df[['Latitude','Longitude']].dtypes
# Out:
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (205539, 39)

# %%
df.to_excel('/content/drive/MyDrive/CAPSTONE/CAPSTONE_PROJECT/0_dataset/2 VALIDATED DATA/validated_data.xlsx', index=False)
